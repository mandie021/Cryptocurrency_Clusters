# %%
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import pandas as pd
from pathlib import Path

# %%
#import csv to df
file = Path('crypto_data.csv')
df = pd.read_csv(file)
df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# 4        0.000000e+00               0
# ...               ...             ...
# 1247     1.283270e+05         1000000
# 1248     2.149121e+07       100000000
# 1249              NaN       233100000
# 1250              NaN        21000000
# 1251              NaN        40000000
#
# [1252 rows x 7 columns]

# %%
#Remove all rows that have at least one null value.
df.isnull().sum()
# Out:
# Unnamed: 0           0
# CoinName             0
# Algorithm            0
# IsTrading            0
# ProofType            0
# TotalCoinsMined    508
# TotalCoinSupply      0
# dtype: int64

# %%
# Delete rows with null values
df = df.dropna()
df
# Out:
#      Unnamed: 0     CoinName    Algorithm  IsTrading ProofType  \
# 0            42      42 Coin       Scrypt       True   PoW/PoS
# 2           404      404Coin       Scrypt       True   PoW/PoS
# 4           808          808      SHA-256       True   PoW/PoS
# 5          1337    EliteCoin          X13       True   PoW/PoS
# 7           BTC      Bitcoin      SHA-256       True       PoW
# ...         ...          ...          ...        ...       ...
# 1242        GAP      Gapcoin       Scrypt       True   PoW/PoS
# 1245        BDX       Beldex  CryptoNight       True       PoW
# 1246        ZEN      Horizen     Equihash       True       PoW
# 1247        XBC  BitcoinPlus       Scrypt       True       PoS
# 1248       DVTC   DivotyCoin       Scrypt      False   PoW/PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 2        1.055185e+09       532000000
# 4        0.000000e+00               0
# 5        2.927942e+10    314159265359
# 7        1.792718e+07        21000000
# ...               ...             ...
# 1242     1.493105e+07       250000000
# 1245     9.802226e+08      1400222610
# 1246     7.296538e+06        21000000
# 1247     1.283270e+05         1000000
# 1248     2.149121e+07       100000000
#
# [744 rows x 7 columns]

# %%
#Discard all cryptocurrencies that are not being traded. 
#filter for currencies that are currently being traded. 
trading_df = df[(df["IsTrading"] != True) ]
trading_df.reset_index()
# Out:
#     index Unnamed: 0               CoinName    Algorithm  IsTrading ProofType  \
# 0     376       ADNT                  Aiden     ScryptOG      False       PoW
# 1     829        ISH  Interstellar Holdings       Scrypt      False       PoS
# 2     832        ICC        Insta Cash Coin      SHA-256      False       PoW
# 3     833       ALQO                   Alqo        Quark      False   PoW/PoS
# 4     841       BCO*             BridgeCoin       Scrypt      False       PoW
# 5     843        MUT            Mutual Coin       Scrypt      False   PoW/PoS
# 6     853       BOXY               BoxyCoin       Scrypt      False       PoW
# 7     864        HBC          HomeBlockCoin          X11      False   PoW/PoS
# 8     868       ACCO               Accolade       Scrypt      False   PoW/PoS
# 9     871       OMGC        OmiseGO Classic       Scrypt      False   PoW/PoS
# 10    874        GOA                GoaCoin    NeoScrypt      False       PoW
# 11    885        ECC                    ECC       Scrypt      False       PoS
# 12    891        SGL                  Sigil    NeoScrypt      False       PoW
# 13    900       CWIS     Crypto Wisdom Coin       Scrypt      False       PoW
# 14    912        BSR           BitSoar Coin          X11      False       PoS
# 15    919      CRDNC          Credence Coin      SHA-256      False   PoW/PoS
# 16    930      BASHC               BashCoin        Skein      False   PoW/PoS
# 17    931        DGM              DigiMoney          X11      False   PoW/PoS
# 18    934        LIZ          Lizus Payment        Skein      False   PoW/PoS
# 19    939      POKER              PokerCoin       Scrypt      False   PoS/PoW
# 20    951      MANNA                  Manna      SHA-256      False       PoW
# 21    953       SERA                 Seraph      PHI1612      False   PoW/PoS
# 22    955       CMOS                  Cosmo        Quark      False       PoW
# 23    956       REDN                  Reden         X16S      False       PoW
# 24    969        FLM              FOLM coin      PHI1612      False       PoW
# 25    975        RAP                Rapture    NeoScrypt      False       PoW
# 26    980        UWC              Uwezocoin       Scrypt      False       PoW
# 27    998        PAR                 Parlay       Scrypt      False       PoS
# 28    999       LTCC     Listerclassic Coin       Scrypt      False   PoW/PoS
# 29   1002        KNG               BetKings          X11      False       PoS
# 30   1003        COG               Cognitio     SHA-256D      False   PoW/PoS
# 31   1008        MRN                Mercoin       Scrypt      False   PoW/PoS
# 32   1010       EXCC           ExchangeCoin     Equihash      False       PoW
# 33   1011        REL               Reliance          X11      False       PoS
# 34   1024        YCE                   MYCE       Scrypt      False   PoW/PoS
# 35   1025        ARO                Arionum      SHA-512      False       PoW
# 36   1028       GOLF               GolfCoin     SHA-256D      False   PoW/PoS
# 37   1033       GMCN             GambleCoin       Scrypt      False       PoS
# 38   1042        XGS               GenesisX        XEVAN      False       PoS
# 39   1043        BIM           BitminerCoin  CryptoNight      False       PoW
# 40   1045        DEI                 Deimos       Scrypt      False       PoW
# 41   1053       BITN           Bitcoin Nova  CryptoNight      False       PoW
# 42   1055     DACASH                 DACash          X11      False       PoW
# 43   1069        AOP               Averopay       Tribus      False   PoW/PoS
# 44   1072       SPLB             SimpleBank    NeoScrypt      False   PoW/PoS
# 45   1090       BRAZ                 Brazio      HMQ1725      False       PoW
# 46   1094     TWISTR                  TWIST      SHA-512      False       PoS
# 47   1098       DACH              DACH Coin        Quark      False       PoS
# 48   1099        AGM               Argoneum      PHI1612      False       PoW
# 49   1113       BBTC           BlakeBitcoin        Blake      False       PoW
# 50   1116        ELT               Electron        Blake      False       PoW
# 51   1132     SCRIBE         Scribe Network    Lyra2REv2      False       PoW
# 52   1153        MPT   Media Protocol Token       Ethash      False       PoW
# 53   1208        TCR              TecraCoin       Lyra2Z      False       PoW
# 54   1210        GEX                  Gexan         PHI2      False   PoW/PoS
# 55   1227        LAX                   LAPO       Lyra2Z      False   PoW/PoS
# 56   1233      SHARD              ShardCoin       Scrypt      False       PoS
# 57   1236      ZILLA             ChainZilla     Equihash      False      DPoW
# 58   1248       DVTC             DivotyCoin       Scrypt      False   PoW/PoS
#
#     TotalCoinsMined       TotalCoinSupply
# 0      8.400000e+07              84000000
# 1      0.000000e+00            1970000000
# 2      0.000000e+00             300000000
# 3      6.526953e+07              57879300
# 4      0.000000e+00              27000000
# 5      0.000000e+00            1000000000
# 6      5.761513e+06             100000000
# 7      0.000000e+00              28000000
# 8      5.573908e+06              50000000
# 9      4.993322e+07              70000000
# 10     3.982139e+06              32000000
# 11     2.500000e+10           25000000000
# 12     0.000000e+00              50000000
# 13     1.763055e+07              24000000
# 14     3.680297e+09            3980000000
# 15     3.427006e+06              25000000
# 16     1.166184e+07              72000000
# 17     3.521630e+06              25000000
# 18     2.985971e+06              69000000
# 19     0.000000e+00             466666667
# 20     2.360478e+09  10044655075.56243680
# 21     1.360250e+06              32000000
# 22     8.928877e+06              11892000
# 23     0.000000e+00              14000000
# 24     0.000000e+00              23001916
# 25     4.478901e+06              21000000
# 26     0.000000e+00             840000000
# 27     3.783270e+06              30000000
# 28     8.094818e+06             110000000
# 29     1.135963e+07               8148139
# 30     6.585845e+05               7500000
# 31     2.533025e+07             100000000
# 32     0.000000e+00              32000000
# 33     7.256580e+06              62000000
# 34     6.361390e+07             250000000
# 35     6.004590e+07             545399000
# 36     0.000000e+00            1713134800
# 37     8.240763e+06              15600000
# 38     0.000000e+00              19000000
# 39     0.000000e+00              50000000
# 40     2.691440e+08            1000000000
# 41     4.844542e+08            1000000000
# 42     2.670924e+07              50000000
# 43     1.859476e+06              36500000
# 44     2.381471e+06              21000000
# 45     7.557979e+07             207000000
# 46     2.000000e+08             200000000
# 47     1.430311e+07              38000000
# 48     1.396958e+07              64000000
# 49     2.059548e+07              21000000
# 50     2.415692e+07            7000000000
# 51     6.040584e+06              32700000
# 52     1.000000e+10           10000000000
# 53     4.087445e+07             210000000
# 54     2.233828e+06              21000000
# 55     1.108683e+10          100000000000
# 56     2.492499e+07             900000000
# 57     1.100007e+07              11000000
# 58     2.149121e+07             100000000

# %%
#Once you have done this, drop the IsTrading column from the dataframe.
clean_df = df.drop(["IsTrading"], axis=1)
clean_df
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 4           808          808      SHA-256   PoW/PoS     0.000000e+00
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# ...         ...          ...          ...       ...              ...
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
# 1248       DVTC   DivotyCoin       Scrypt   PoW/PoS     2.149121e+07
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 4                  0
# 5       314159265359
# 7           21000000
# ...              ...
# 1242       250000000
# 1245      1400222610
# 1246        21000000
# 1247         1000000
# 1248       100000000
#
# [744 rows x 6 columns]

# %%
#Filter for cryptocurrencies that have been mined. That is, the total coins mined should be greater than zero.
mined_df = clean_df[(df["TotalCoinsMined"] > 0) ]
mined_df
# Out:
#      Unnamed: 0     CoinName    Algorithm ProofType  TotalCoinsMined  \
# 0            42      42 Coin       Scrypt   PoW/PoS     4.199995e+01
# 2           404      404Coin       Scrypt   PoW/PoS     1.055185e+09
# 5          1337    EliteCoin          X13   PoW/PoS     2.927942e+10
# 7           BTC      Bitcoin      SHA-256       PoW     1.792718e+07
# 8           ETH     Ethereum       Ethash       PoW     1.076842e+08
# ...         ...          ...          ...       ...              ...
# 1242        GAP      Gapcoin       Scrypt   PoW/PoS     1.493105e+07
# 1245        BDX       Beldex  CryptoNight       PoW     9.802226e+08
# 1246        ZEN      Horizen     Equihash       PoW     7.296538e+06
# 1247        XBC  BitcoinPlus       Scrypt       PoS     1.283270e+05
# 1248       DVTC   DivotyCoin       Scrypt   PoW/PoS     2.149121e+07
#
#      TotalCoinSupply
# 0                 42
# 2          532000000
# 5       314159265359
# 7           21000000
# 8                  0
# ...              ...
# 1242       250000000
# 1245      1400222610
# 1246        21000000
# 1247         1000000
# 1248       100000000
#
# [577 rows x 6 columns]

# %%
#In order for your dataset to be comprehensible to a machine learning algorithm, its data should be numeric. 
#Since the coin names do not contribute to the analysis of the data, 
#delete the CoinName from the original dataframe.
new_df = mined_df.drop(["CoinName", "Unnamed: 0"], axis='columns')
new_df
# Out:
#         Algorithm ProofType  TotalCoinsMined TotalCoinSupply
# 0          Scrypt   PoW/PoS     4.199995e+01              42
# 2          Scrypt   PoW/PoS     1.055185e+09       532000000
# 5             X13   PoW/PoS     2.927942e+10    314159265359
# 7         SHA-256       PoW     1.792718e+07        21000000
# 8          Ethash       PoW     1.076842e+08               0
# ...           ...       ...              ...             ...
# 1242       Scrypt   PoW/PoS     1.493105e+07       250000000
# 1245  CryptoNight       PoW     9.802226e+08      1400222610
# 1246     Equihash       PoW     7.296538e+06        21000000
# 1247       Scrypt       PoS     1.283270e+05         1000000
# 1248       Scrypt   PoW/PoS     2.149121e+07       100000000
#
# [577 rows x 4 columns]

# %%
#check data types
new_df.dtypes
# Out:
# Algorithm           object
# ProofType           object
# TotalCoinsMined    float64
# TotalCoinSupply     object
# dtype: object

# %%
#change TotalCoinSupply to float
new_df['TotalCoinSupply'] = new_df['TotalCoinSupply'].astype(float)
new_df.dtypes
# Out:
# Algorithm           object
# ProofType           object
# TotalCoinsMined    float64
# TotalCoinSupply    float64
# dtype: object

# %%
#convert the remaining features with text values, Algorithm and ProofType, into numerical data. 
#use Pandas to create dummy variables
dummies_df = pd.get_dummies(new_df, columns = ['Algorithm', 'ProofType'])
dummies_df
# Out:
#       TotalCoinsMined  TotalCoinSupply  Algorithm_1GB AES Pattern Search  \
# 0        4.199995e+01     4.200000e+01                                 0
# 2        1.055185e+09     5.320000e+08                                 0
# 5        2.927942e+10     3.141593e+11                                 0
# 7        1.792718e+07     2.100000e+07                                 0
# 8        1.076842e+08     0.000000e+00                                 0
# ...               ...              ...                               ...
# 1242     1.493105e+07     2.500000e+08                                 0
# 1245     9.802226e+08     1.400223e+09                                 0
# 1246     7.296538e+06     2.100000e+07                                 0
# 1247     1.283270e+05     1.000000e+06                                 0
# 1248     2.149121e+07     1.000000e+08                                 0
#
#       Algorithm_536  Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# 0                 0                  0                   0                0
# 2                 0                  0                   0                0
# 5                 0                  0                   0                0
# 7                 0                  0                   0                0
# 8                 0                  0                   0                0
# ...             ...                ...                 ...              ...
# 1242              0                  0                   0                0
# 1245              0                  0                   0                0
# 1246              0                  0                   0                0
# 1247              0                  0                   0                0
# 1248              0                  0                   0                0
#
#       Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  ...  \
# 0                     0                  0              0  ...
# 2                     0                  0              0  ...
# 5                     0                  0              0  ...
# 7                     0                  0              0  ...
# 8                     0                  0              0  ...
# ...                 ...                ...            ...  ...
# 1242                  0                  0              0  ...
# 1245                  0                  0              0  ...
# 1246                  0                  0              0  ...
# 1247                  0                  0              0  ...
# 1248                  0                  0              0  ...
#
#       ProofType_PoW/PoS  ProofType_PoW/PoS   ProofType_PoW/PoW  \
# 0                     1                   0                  0
# 2                     1                   0                  0
# 5                     1                   0                  0
# 7                     0                   0                  0
# 8                     0                   0                  0
# ...                 ...                 ...                ...
# 1242                  1                   0                  0
# 1245                  0                   0                  0
# 1246                  0                   0                  0
# 1247                  0                   0                  0
# 1248                  1                   0                  0
#
#       ProofType_PoW/nPoS  ProofType_Pos  ProofType_Proof of Authority  \
# 0                      0              0                             0
# 2                      0              0                             0
# 5                      0              0                             0
# 7                      0              0                             0
# 8                      0              0                             0
# ...                  ...            ...                           ...
# 1242                   0              0                             0
# 1245                   0              0                             0
# 1246                   0              0                             0
# 1247                   0              0                             0
# 1248                   0              0                             0
#
#       ProofType_Proof of Trust  ProofType_TPoS  \
# 0                            0               0
# 2                            0               0
# 5                            0               0
# 7                            0               0
# 8                            0               0
# ...                        ...             ...
# 1242                         0               0
# 1245                         0               0
# 1246                         0               0
# 1247                         0               0
# 1248                         0               0
#
#       ProofType_Zero-Knowledge Proof  ProofType_dPoW/PoW
# 0                                  0                   0
# 2                                  0                   0
# 5                                  0                   0
# 7                                  0                   0
# 8                                  0                   0
# ...                              ...                 ...
# 1242                               0                   0
# 1245                               0                   0
# 1246                               0                   0
# 1247                               0                   0
# 1248                               0                   0
#
# [577 rows x 101 columns]

# %%
# Examine the number of rows and columns of your dataset now. How did they change?

# %%
#Standardize your dataset so that columns that contain larger values do not unduly influence the outcome.

# %%
#Perform dimensionality reduction with PCA. 
#Rather than specify the number of principal components when you instantiate the PCA model, 
#it is possible to state the desired explained variance.
#For this project, preserve 90% of the explained variance in dimensionality reduction. 
#How did the number of the features change?

# %%
#Next, further reduce the dataset dimensions with t-SNE and visually inspect the results. 
#In order to accomplish this task, run t-SNE on the principal components: the output of the PCA transformation. 
#Then create a scatter plot of the t-SNE output. Observe whether there are distinct clusters or not.

# %%
#Create an elbow plot to identify the best number of clusters. 
#Use a for-loop to determine the inertia for each k between 1 through 10. 
#Determine, if possible, where the elbow of the plot is, and at which value of k it appears.
